# %%
# !python Generate_Players.py
# Out:
# 150 Players generated successfully.

# %%
from utils import load_players

players = load_players()
print(players[0].name)
# Out:
# Players loaded: 150
# sehwag iyer

# %%
from team import Team
from player import Player

# create a team
team = Team("MI")

# create a sample player
player = Player("Virat Kohli", "India", "Batsman", 50, 90)

# check if team can buy
print(team.can_buy(player, 50))

# buy the player
team.buy(player, 50)

# check squad size
print("Players in squad:", len(team.squad))

# check purse left
print("Remaining purse:", team.purse)
# Out:
# True
# MI bought Virat Kohli
# Players in squad: 1
# Remaining purse: 1950

# %%
# !python main.py
# Out:
# Players loaded: 150
# AUCTION STARTED
#
# SRH bought sehwag iyer
# RCB bought Surya Reddy
# RCB bought Shubman Rathan
# RR bought Dhoni Kohli
# MI bought Virat Sharma
# GT bought Shubman Gill
# SRH bought Ravindra Verma
# KKR bought Virat Verma
# RCB bought Rohit Reddy
# KKR bought Yuvaraj Rahul
# KKR bought Virat Kathik
# CSK bought Sanju Verma
# DC bought Surya Verma
# CSK bought KL Rahul
# MI bought Hardik Pandya
# RCB bought Shubman Verma
# RCB bought Rohit Sumbet
# MI bought Shubman Verma
# SRH bought Hardik Rahul
# MI bought Sanju Verma
# GT bought KL Sumbet
# RR bought Shubman Sumbet
# GT bought Ravindra Rahul
# CSK bought Ravindra Verma
# RCB bought Surya Reddy
# CSK bought Rohit Kohli
# RR bought Hardik Sumbet
# RCB bought Rishabh Rathan
# GT bought Sachin Kohli
# DC bought Yuvaraj Kathik
# RR bought Yuvaraj Kohli
# GT bought Sachin Kohli
# RR bought Sachin Kathik
# CSK bought Ishan Rathan
# KKR bought sehwag Sumbet
# MI bought Hardik Sumbet
# MI bought Sachin iyer
# ...
